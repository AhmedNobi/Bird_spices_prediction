# %% [markdown]
# <a href="https://colab.research.google.com/github/AhmedNobi/Bird_spices_prediction/blob/main/Bird_Species_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bird Species Prediction

# %%
# Load the Drive helper and mount
from google.colab import drive

# This will prompt for authorization.
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# First we will mount our google drive on colab so that we can use the dataset directly from our drive. For this you first need to upload the data on your drive and then mount the drive on colab.

# %%
# After executing the cell above, Drive files will be present in "/content/drive/My Drive".
# !ls "/content/drive/My Drive"
# Out:
# '1335-أحمد مصطفى شحاتة نوبي.pdf'
# 'Ahmed Mostafa Shehata.pdf'
# 'Ahmed Nobi'
# 'Ahmed Nobi resume.pdf'
# 'Ahmed'\''s Resume DS (1).pdf'
# "Ahmed's Resume DS.pdf"
# 'Ahmed'\''s Resume SWE (1).pdf'
# "Ahmed's Resume SWE.pdf"
# 'Bird Speciees Dataset'
#  CI
#  Classroom
# 'Colab Notebooks'
# 'Copy of 0.png'
# 'Copy of 100.png'
# 'Copy of 101.png'
# 'Copy of 103.png'
# 'Copy of 105.png'
# 'Copy of 106.png'
# 'Copy of 108.png'
# 'Copy of 109.png'
# 'Copy of 110.png'
# 'Copy of 111.png'
# 'Copy of 112.png'
# 'Copy of 113.png'
# 'Copy of 114.png'
# 'Copy of 115.png'
# 'Copy of 116.png'
# 'Copy of 117.png'
# 'Copy of 118.png'
# 'Copy of 11.png'
# 'Copy of 120.png'
# 'Copy of 121.png'
# 'Copy of 122.png'
# 'Copy of 123.png'
# 'Copy of 127.png'
# 'Copy of 129.png'
# 'Copy of 12.png'
# 'Copy of 130.png'
# 'Copy of 131.png'
# 'Copy of 132.png'
# 'Copy of 134.png'
# 'Copy of 135.png'
# 'Copy of 136.png'
# 'Copy of 137.png'
# 'Copy of 138.png'
# 'Copy of 139.png'
# 'Copy of 13.png'
# 'Copy of 140.png'
# 'Copy of 141.png'
# 'Copy of 143.png'
# 'Copy of 144.png'
# 'Copy of 145.png'
# 'Copy of 146.png'
# 'Copy of 149.png'
# 'Copy of 14.png'
# 'Copy of 150.png'
# 'Copy of 151.png'
# 'Copy of 152.png'
# 'Copy of 153.png'
# 'Copy of 154.png'
# 'Copy of 156.png'
# 'Copy of 15.png'
# 'Copy of 160.png'
# 'Copy of 161.png'
# 'Copy of 162.png'
# 'Copy of 164.png'
# 'Copy of 165.png'
# 'Copy of 166.png'
# 'Copy of 16.png'
# 'Copy of 170.png'
# 'Copy of 172.png'
# 'Copy of 173.png'
# 'Copy of 175.png'
# 'Copy of 177.png'
# 'Copy of 178.png'
# 'Copy of 179.png'
# 'Copy of 180.png'
# 'Copy of 181.png'
# 'Copy of 182.png'
# 'Copy of 183.png'
# 'Copy of 184.png'
# 'Copy of 187.png'
# 'Copy of 188.png'
# 'Copy of 189.png'
# 'Copy of 18.png'
# 'Copy of 190.png'
# 'Copy of 191.png'
# 'Copy of 192.png'
# 'Copy of 193.png'
# 'Copy of 194.png'
# 'Copy of 195.png'
# 'Copy of 196.png'
# 'Copy of 199.png'
# 'Copy of 1.png'
# 'Copy of 200.png'
# 'Copy of 201.png'
# 'Copy of 202.png'
# 'Copy of 203.png'
# 'Copy of 205.png'
# 'Copy of 207.png'
# 'Copy of 208.png'
# 'Copy of 209.png'
# 'Copy of 20.png'
# 'Copy of 210.png'
# 'Copy of 211.png'
# 'Copy of 811.png'
# 'Copy of 812.png'
# 'Copy of 813.png'
# 'Copy of 815.png'
# 'Copy of 816.png'
# 'Copy of 817.png'
# 'Copy of 819.png'
# 'Copy of 81.png'
# 'Copy of 820.png'
# 'Copy of 821.png'
# 'Copy of 822.png'
# 'Copy of 823.png'
# 'Copy of 824.png'
# 'Copy of 826.png'
# 'Copy of 827.png'
# 'Copy of 828.png'
# 'Copy of 829.png'
# 'Copy of 830.png'
# 'Copy of 831.png'
# 'Copy of 832.png'
# 'Copy of 835.png'
# 'Copy of 836.png'
# 'Copy of 837.png'
# 'Copy of 838.png'
# 'Copy of 839.png'
# 'Copy of 83.png'
# 'Copy of 840.png'
# 'Copy of 841.png'
# 'Copy of 842.png'
# 'Copy of 843.png'
# 'Copy of 846.png'
# 'Copy of 847.png'
# 'Copy of 848.png'
# 'Copy of 849.png'
# 'Copy of 84.png'
# 'Copy of 850.png'
# 'Copy of 851.png'
# 'Copy of 852.png'
# 'Copy of 85.png'
# 'Copy of 86.png'
# 'Copy of 88.png'
# 'Copy of 89.png'
# 'Copy of 8.png'
# 'Copy of 90.png'
# 'Copy of 91.png'
# 'Copy of 92.png'
# 'Copy of 93.png'
# 'Copy of 94.png'
# 'Copy of 97.png'
# 'Copy of 99.png'
# 'Copy of 9.png'
# 'Copy of databaseproject gahez l githup (1).zip'
# 'Copy of databaseproject gahez l githup (2).zip'
# 'Copy of databaseproject gahez l githup.zip'
# 'Copy of Junior Training Sheet - template - V7.0.gsheet'
# 'Copy of Read me.gdoc'
#  cpp_containers.pptx
# 'CS 2021'
# 'CV 21'
# 'Deep Learning for Deepfakes Creation and Detection: A Survey (2020).gdoc'
#  DSPToolbox
# 'elevation 2.rar'
#  epldata_final.csv.gsheet
# 'Final Presentation.gslides'
#  FPL_2018_19_Wk0.csv.gsheet
# 'HPC Document.gdoc'
#  image_2021-12-12_235522.png
# 'Img - Img Synthesis (Nobi).gdoc'
# 'Movie Success Predictor.gdoc'
# 'My Video.mp4'
#  NOBI.gsheet
# 'Predict Movie Success Report.gdoc'
# 'Project proposal.gdoc'
#  Resume.gdoc
# 'Scenes training set'
#  Script.gdoc
# 'Slamo 3likm.zip'
#  TAsk1-20200412T082353Z-001.zip
#  test
# 'test (1)'
#  Topic3.py
#  train
# 'train (1)'
# 'Untitled document (1).gdoc'
# 'Untitled document.gdoc'
# 'Untitled spreadsheet.gsheet'
# 'Virtual Real Person Control(Mimico) 3rd.gslides'
# 'You know nothing Ahmed Nobi.gsheet'
# 'أحمد مصطفى شحاتة نوبي - 926.pdf'
# 'الايميل يا نوبي github.txt'

# %% [markdown]
# After mounting our drive we will locate the folder where our data is stored to use it in our colab notebook. Here you can see that all the folders I have in my drive and 'Bird Species Dataset' contains the images that we will work on.

# %%
# Library imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import cv2
import random
import tensorflow as tf

from matplotlib.image import imread
from os import listdir
from sklearn.preprocessing import  LabelBinarizer
from keras.preprocessing import image
from keras.preprocessing.image import img_to_array, array_to_img
from tensorflow.keras.optimizers import Adam
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Activation, Flatten, Dropout, Dense
from sklearn.model_selection import train_test_split

# %% [markdown]
# We will start by importing some required libraries.

# %%
# Plotting 12 images to check dataset
plt.figure(figsize=(12,12))
path = "/content/drive/My Drive/Bird Speciees Dataset/AMERICAN GOLDFINCH"
for i in range(1,17):
    plt.subplot(4,4,i)
    plt.tight_layout()
    rand_img = imread(path +'/'+ random.choice(sorted(listdir(path))))
    plt.imshow(rand_img)
    plt.xlabel(rand_img.shape[1], fontsize = 10)
    plt.ylabel(rand_img.shape[0], fontsize = 10)

# %% [markdown]
# Let's visualize some of the bird images that we will be working on. Also we will observe x and y dimensions of the image.

# %%
# Setting path and creating empty list
dir = "/content/drive/My Drive/Bird Speciees Dataset"
root_dir = listdir(dir)
image_list, label_list = [], []

# %% [markdown]
# Setting the root directory for the dataset and storing all the floders name of the dataset. We will also create 2 empty list for image and lables.

# %%
# Reading and converting image to numpy array
for directory in root_dir:
  for files in listdir(f"{dir}/{directory}"):
    image_path = f"{dir}/{directory}/{files}"
    image = cv2.imread(image_path)
    image = img_to_array(image)
    image_list.append(image)
    label_list.append(directory)

# %% [markdown]
# Next we will read all the images and convert it into array and appending the list created above with the image and its label.

# %%
# Visualize the number of classes count
label_counts = pd.DataFrame(label_list).value_counts()
label_counts
# Out:
# AMERICAN GOLDFINCH    143
# EMPEROR PENGUIN       139
# DOWNY WOODPECKER      137
# FLAMINGO              132
# CARMINE BEE-EATER     131
# BARN OWL              129
# dtype: int64

# %% [markdown]
# Check for class imbalance.

# %%
# Storing number of classes
num_classes = len(label_counts)
num_classes
# Out:
# 6

# %% [markdown]
# Next we will find out the number of classes that we will be working on.

# %%
# Checking input image shape
image_list[0].shape
# Out:
# (224, 224, 3)

# %% [markdown]
# Checking the size of the single image.

# %%
# Checking labels shape 
label_list = np.array(label_list)
label_list.shape
# Out:
# (811,)

# %% [markdown]
# Checking the shape of image labels which will be equal to the number of images we are going to work with.

# %%
# Splitting dataset
x_train, x_test, y_train, y_test = train_test_split(image_list, label_list, test_size=0.2, random_state = 10)

# %% [markdown]
# Now we will split the data into training and testing using train_test_split() of sklearn.

# %%
# Normalize and reshape data
x_train = np.array(x_train, dtype=np.float16) / 225.0
x_test = np.array(x_test, dtype=np.float16) / 225.0
x_train = x_train.reshape( -1, 224,224,3)
x_test = x_test.reshape( -1, 224,224,3)

# %% [markdown]
# Next we will normalize the images by dividing them with 255. Also, we will reshape x_train and x_test.

# %%
# Label binarizing
lb = LabelBinarizer()
y_train = lb.fit_transform(y_train)
y_test = lb.fit_transform(y_test)
print(lb.classes_)
# Out:
# ['AMERICAN GOLDFINCH' 'BARN OWL' 'CARMINE BEE-EATER' 'DOWNY WOODPECKER'
#  'EMPEROR PENGUIN' 'FLAMINGO']

# %% [markdown]
# Next we will use label binarizer to one hot encode our y data. We will also print the sequence of the classes.

# %%
# Splitting the training data set into training and validation data sets
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size = 0.2)

# %% [markdown]
# Now we will split the training data to validation and training data.

# %%
# Building model architecture
model = Sequential()
model.add(Conv2D(8, (3, 3), padding="same",input_shape=(224,224,3), activation="relu"))
model.add(MaxPooling2D(pool_size=(3, 3)))
model.add(Conv2D(16, (3, 3), padding="same", activation="relu"))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(32, (3, 3), padding="same", activation="relu"))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())
model.add(Dense(32, activation="relu"))
model.add(Dense(num_classes, activation="softmax"))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 224, 224, 8)       224
#
#  max_pooling2d (MaxPooling2D  (None, 74, 74, 8)        0
#  )
#
#  conv2d_1 (Conv2D)           (None, 74, 74, 16)        1168
#
#  max_pooling2d_1 (MaxPooling  (None, 37, 37, 16)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 37, 37, 32)        4640
#
#  max_pooling2d_2 (MaxPooling  (None, 18, 18, 32)       0
#  2D)
#
#  flatten (Flatten)           (None, 10368)             0
#
#  dense (Dense)               (None, 32)                331808
#
#  dense_1 (Dense)             (None, 6)                 198
#
# =================================================================
# Total params: 338,038
# Trainable params: 338,038
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Next we will create a network architecture for the model. We have used different types of layers according to their features namely Conv_2d (It is used to create a convolutional kernel that is convolved with the input layer to produce the output tensor), max_pooling2d (It is a downsampling technique which takes out the maximum value over the window defined by poolsize), flatten (It flattens the input and creates a 1D output), Dense (Dense layer produce the output as the dot product of input and kernel). In the last layer we will use softmax as the activation function because it is a multi class classification problem.

# %%
# Compiling model
model.compile(loss = 'categorical_crossentropy', optimizer = Adam(0.0005),metrics=['accuracy'])

# %% [markdown]
# While compiling the model we need to set the type of loss which will be Categorical Crossentropy for our model alongwith this we also need to set the optimizer and the metrics respectively.

# %%
# Training the model
epochs = 50
batch_size = 128
history = model.fit(x_train, y_train, batch_size = batch_size, epochs = epochs, validation_data = (x_val, y_val))
# Out:
# Epoch 1/50
# 5/5 [==============================] - 11s 191ms/step - loss: 1.7898 - accuracy: 0.2066 - val_loss: 1.7671 - val_accuracy: 0.1692
# Epoch 2/50
# 5/5 [==============================] - 0s 80ms/step - loss: 1.7500 - accuracy: 0.1950 - val_loss: 1.7166 - val_accuracy: 0.2462
# Epoch 3/50
# 5/5 [==============================] - 0s 77ms/step - loss: 1.6723 - accuracy: 0.3649 - val_loss: 1.6493 - val_accuracy: 0.5462
# Epoch 4/50
# 5/5 [==============================] - 0s 77ms/step - loss: 1.5799 - accuracy: 0.4961 - val_loss: 1.6125 - val_accuracy: 0.3923
# Epoch 5/50
# 5/5 [==============================] - 0s 81ms/step - loss: 1.4906 - accuracy: 0.4575 - val_loss: 1.4819 - val_accuracy: 0.4615
# Epoch 6/50
# 5/5 [==============================] - 0s 80ms/step - loss: 1.3697 - accuracy: 0.5541 - val_loss: 1.3463 - val_accuracy: 0.6154
# Epoch 7/50
# 5/5 [==============================] - 0s 79ms/step - loss: 1.1965 - accuracy: 0.6737 - val_loss: 1.2341 - val_accuracy: 0.5692
# Epoch 8/50
# 5/5 [==============================] - 0s 78ms/step - loss: 1.0616 - accuracy: 0.6641 - val_loss: 1.1142 - val_accuracy: 0.6692
# Epoch 9/50
# 5/5 [==============================] - 0s 81ms/step - loss: 0.9673 - accuracy: 0.6718 - val_loss: 1.0321 - val_accuracy: 0.6308
# Epoch 10/50
# 5/5 [==============================] - 0s 78ms/step - loss: 0.9260 - accuracy: 0.7162 - val_loss: 0.9764 - val_accuracy: 0.6769
# Epoch 11/50
# 5/5 [==============================] - 0s 78ms/step - loss: 0.8290 - accuracy: 0.7104 - val_loss: 0.9628 - val_accuracy: 0.6769
# Epoch 12/50
# 5/5 [==============================] - 0s 79ms/step - loss: 0.7806 - accuracy: 0.7220 - val_loss: 0.9217 - val_accuracy: 0.7000
# Epoch 13/50
# 5/5 [==============================] - 0s 80ms/step - loss: 0.7706 - accuracy: 0.7143 - val_loss: 0.9516 - val_accuracy: 0.6615
# Epoch 14/50
# 5/5 [==============================] - 0s 77ms/step - loss: 0.7011 - accuracy: 0.7336 - val_loss: 0.8449 - val_accuracy: 0.7077
# Epoch 15/50
# 5/5 [==============================] - 0s 77ms/step - loss: 0.6663 - accuracy: 0.7625 - val_loss: 0.8209 - val_accuracy: 0.7000
# Epoch 16/50
# 5/5 [==============================] - 0s 78ms/step - loss: 0.6206 - accuracy: 0.7568 - val_loss: 0.7701 - val_accuracy: 0.7077
# Epoch 17/50
# 5/5 [==============================] - 0s 77ms/step - loss: 0.6062 - accuracy: 0.7915 - val_loss: 0.7636 - val_accuracy: 0.7462
# Epoch 18/50
# 5/5 [==============================] - 0s 77ms/step - loss: 0.5883 - accuracy: 0.8089 - val_loss: 0.7633 - val_accuracy: 0.7154
# Epoch 19/50
# 5/5 [==============================] - 0s 80ms/step - loss: 0.5855 - accuracy: 0.7761 - val_loss: 0.8062 - val_accuracy: 0.6769
# Epoch 20/50
# 5/5 [==============================] - 0s 77ms/step - loss: 0.5549 - accuracy: 0.8205 - val_loss: 0.7540 - val_accuracy: 0.7000
# Epoch 21/50
# 5/5 [==============================] - 0s 78ms/step - loss: 0.4947 - accuracy: 0.8185 - val_loss: 0.6924 - val_accuracy: 0.7385
# Epoch 22/50
# 5/5 [==============================] - 0s 77ms/step - loss: 0.4520 - accuracy: 0.8417 - val_loss: 0.6585 - val_accuracy: 0.7615
# Epoch 23/50
# 5/5 [==============================] - 0s 79ms/step - loss: 0.4493 - accuracy: 0.8494 - val_loss: 0.6766 - val_accuracy: 0.7615
# Epoch 24/50
# 5/5 [==============================] - 0s 80ms/step - loss: 0.4246 - accuracy: 0.8552 - val_loss: 0.6380 - val_accuracy: 0.7769
# Epoch 25/50
# 5/5 [==============================] - 0s 78ms/step - loss: 0.3690 - accuracy: 0.8649 - val_loss: 0.6537 - val_accuracy: 0.7231
# Epoch 26/50
# 5/5 [==============================] - 0s 79ms/step - loss: 0.3606 - accuracy: 0.8726 - val_loss: 0.6093 - val_accuracy: 0.7692
# Epoch 27/50
# 5/5 [==============================] - 0s 80ms/step - loss: 0.3429 - accuracy: 0.9015 - val_loss: 0.6057 - val_accuracy: 0.8000
# Epoch 28/50
# 5/5 [==============================] - 0s 78ms/step - loss: 0.3130 - accuracy: 0.9131 - val_loss: 0.6310 - val_accuracy: 0.7692
# Epoch 29/50
# 5/5 [==============================] - 0s 80ms/step - loss: 0.3041 - accuracy: 0.8919 - val_loss: 0.6106 - val_accuracy: 0.7923
# Epoch 30/50
# 5/5 [==============================] - 0s 79ms/step - loss: 0.3278 - accuracy: 0.9093 - val_loss: 0.6139 - val_accuracy: 0.8154
# Epoch 31/50
# 5/5 [==============================] - 0s 78ms/step - loss: 0.3572 - accuracy: 0.8668 - val_loss: 0.8442 - val_accuracy: 0.7231
# Epoch 32/50
# 5/5 [==============================] - 0s 77ms/step - loss: 0.4595 - accuracy: 0.8263 - val_loss: 0.6010 - val_accuracy: 0.7692
# Epoch 33/50
# 5/5 [==============================] - 0s 78ms/step - loss: 0.3041 - accuracy: 0.8977 - val_loss: 0.7265 - val_accuracy: 0.7385
# Epoch 34/50
# 5/5 [==============================] - 0s 80ms/step - loss: 0.3092 - accuracy: 0.8938 - val_loss: 0.5551 - val_accuracy: 0.8231
# Epoch 35/50
# 5/5 [==============================] - 0s 78ms/step - loss: 0.2804 - accuracy: 0.9344 - val_loss: 0.5552 - val_accuracy: 0.8154
# Epoch 36/50
# 5/5 [==============================] - 0s 77ms/step - loss: 0.2287 - accuracy: 0.9614 - val_loss: 0.5265 - val_accuracy: 0.7923
# Epoch 37/50
# 5/5 [==============================] - 0s 77ms/step - loss: 0.2213 - accuracy: 0.9402 - val_loss: 0.4958 - val_accuracy: 0.8154
# Epoch 38/50
# 5/5 [==============================] - 0s 79ms/step - loss: 0.1924 - accuracy: 0.9537 - val_loss: 0.5514 - val_accuracy: 0.8077
# Epoch 39/50
# 5/5 [==============================] - 0s 78ms/step - loss: 0.2003 - accuracy: 0.9517 - val_loss: 0.5836 - val_accuracy: 0.8308
# Epoch 40/50
# 5/5 [==============================] - 0s 80ms/step - loss: 0.1840 - accuracy: 0.9421 - val_loss: 0.5075 - val_accuracy: 0.8385
# Epoch 41/50
# 5/5 [==============================] - 0s 81ms/step - loss: 0.1670 - accuracy: 0.9633 - val_loss: 0.5135 - val_accuracy: 0.8154
# Epoch 42/50
# 5/5 [==============================] - 0s 77ms/step - loss: 0.1396 - accuracy: 0.9749 - val_loss: 0.5065 - val_accuracy: 0.8385
# Epoch 43/50
# 5/5 [==============================] - 0s 81ms/step - loss: 0.1571 - accuracy: 0.9730 - val_loss: 0.5576 - val_accuracy: 0.8462
# Epoch 44/50
# 5/5 [==============================] - 0s 78ms/step - loss: 0.1526 - accuracy: 0.9653 - val_loss: 0.5351 - val_accuracy: 0.8308
# Epoch 45/50
# 5/5 [==============================] - 0s 81ms/step - loss: 0.1432 - accuracy: 0.9710 - val_loss: 0.5016 - val_accuracy: 0.8308
# Epoch 46/50
# 5/5 [==============================] - 0s 79ms/step - loss: 0.1147 - accuracy: 0.9865 - val_loss: 0.4888 - val_accuracy: 0.8385
# Epoch 47/50
# 5/5 [==============================] - 0s 77ms/step - loss: 0.1290 - accuracy: 0.9691 - val_loss: 0.5561 - val_accuracy: 0.8308
# Epoch 48/50
# 5/5 [==============================] - 0s 79ms/step - loss: 0.1537 - accuracy: 0.9595 - val_loss: 0.4759 - val_accuracy: 0.8308
# Epoch 49/50
# 5/5 [==============================] - 0s 79ms/step - loss: 0.1492 - accuracy: 0.9556 - val_loss: 0.5403 - val_accuracy: 0.8538
# Epoch 50/50
# 5/5 [==============================] - 0s 71ms/step - loss: 0.1143 - accuracy: 0.9749 - val_loss: 0.5468 - val_accuracy: 0.8308

# %% [markdown]
# Fitting the model with the data and finding out the accuracy at each epoch to see how our model is learning. Now we will train our model on 50 epochs and a batch size of 128. You can try using more number of epochs to increase accuracy but here we can see that the model has already reached a very high accuracy so we don't need to run it for more. During each epochs we can see how the model is performing by viewing the training and validation accuracy.

# %%
# Saving model
model.save("/content/drive/My Drive/bird_species.h5")

# %% [markdown]
# Now we will save the model in h5 format to use it later for prediction.

# %%
#Plot the training history
plt.figure(figsize=(12, 5))
plt.plot(history.history['accuracy'], color='r')
plt.plot(history.history['val_accuracy'], color='b')
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['train', 'val'])
plt.show()

# %% [markdown]
# Next we will plot the accuracy of the model for the training history.

# %%
#Plot the loss history
plt.figure(figsize=(12, 5))
plt.plot(history.history['loss'], color='r')
plt.plot(history.history['val_loss'], color='b')
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(['train', 'val'])
plt.show()

# %% [markdown]
# Here we will plot the loss of the model for the training history.

# %%
# Calculating test accuracy
scores = model.evaluate(x_test, y_test)
print(f"Test Accuracy: {scores[1]*100}")
# Out:
# 6/6 [==============================] - 0s 38ms/step - loss: 0.3562 - accuracy: 0.8589
# Test Accuracy: 85.88957190513611

# %% [markdown]
# Evaluating the model to know the accuracy of the model on the test data.

# %%
# Storing predictions
y_pred = model.predict(x_test)

# %% [markdown]
# Here we are storing prediction on test data.

# %%
# Plotting image to compare
img = array_to_img(x_test[5])
img
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7FA547388C10>

# %% [markdown]
# Visualizing one of the image which we will be further used for prediction.

# %%
# Finding max value from predition list and comaparing original value vs predicted
labels = lb.classes_
print(labels)
print("Originally : ",labels[np.argmax(y_test[5])])
print("Predicted : ",labels[np.argmax(y_pred[5])])
# Out:
# ['AMERICAN GOLDFINCH' 'BARN OWL' 'CARMINE BEE-EATER' 'DOWNY WOODPECKER'
#  'EMPEROR PENGUIN' 'FLAMINGO']
# Originally :  AMERICAN GOLDFINCH
# Predicted :  AMERICAN GOLDFINCH

# %% [markdown]
# Now, we will create list of labels using object of label binarizer. We will print that list and finally we will print out the prediction and the original label of the image we visualized above using argmax().

# %% [markdown]
# # Conclusion:

# %% [markdown]
# We started with loading the dataset into google colab using google drive and visualizing the images. Normalizing is an important step when working with any type of dataset. After that we created a CNN Model which is further used for predicting the bird species using the image supplied to model.

# %% [markdown]
# # Scope:

# %% [markdown]
# This project can be used for educational purposes to get a better understanding of how to create network architecture for a CNN model. You can further hyper parameter tune this model to reach a higher accuracy. It can be used by bird sanctuaries to identify different types of birds.
